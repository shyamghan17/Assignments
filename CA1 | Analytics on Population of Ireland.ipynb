# %% [markdown]
# ### Import Library

# %%
# Import library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
#
# import scipy as stats

import warnings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[268], line 6
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
# ----> 6 import seaborn as sns
#       8 import scipy as stats
#      10 import warnings
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/__init__.py:6
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
# ----> 6 from .regression import *  # noqa: F401,F403
#       7 from .categorical import *  # noqa: F401,F403
#       8 from .distributions import *  # noqa: F401,F403
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/regression.py:7
#       5 import numpy as np
#       6 import pandas as pd
# ----> 7 from scipy.spatial import distance
#       8 import matplotlib as mpl
#       9 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'scipy.spatial'

# %% [markdown]
# ### Set option in pandas to display all rows and columns in dataset

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ### Ignore library Deprecated warning messages

# %%
def ignore_warning(): # define function 
    return warnings.filterwarnings(action='ignore', category= DeprecationWarning, module=r'.*randpool')

ignore_warning() # function call

# %% [markdown]
# ### Load Dataset

# %%
def load_dataset(dataset_url): # define function
    return  pd.read_csv(dataset_url) # to read csv data
 
# call function load_dataset() and store dataset value in population_dataframe
population_dataframe = load_dataset('PEA04.20231018T191000.csv')

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
# Dimensions of dataset
population_dataframe.shape
# Out:
# (6669, 7)

# %%
# Gives top 5 rows of dataset
population_dataframe.head(30)
# Out:
#                             STATISTIC Label  Year    Age Group         Sex  \
# 0   Estimated Population (Persons in April)  2011  0 - 4 years  Both sexes
# 1   Estimated Population (Persons in April)  2011  0 - 4 years  Both sexes
# 2   Estimated Population (Persons in April)  2011  0 - 4 years  Both sexes
# 3   Estimated Population (Persons in April)  2011  0 - 4 years  Both sexes
# 4   Estimated Population (Persons in April)  2011  0 - 4 years  Both sexes
# 5   Estimated Population (Persons in April)  2011  0 - 4 years  Both sexes
# 6   Estimated Population (Persons in April)  2011  0 - 4 years  Both sexes
# 7   Estimated Population (Persons in April)  2011  0 - 4 years  Both sexes
# 8   Estimated Population (Persons in April)  2011  0 - 4 years  Both sexes
# 9   Estimated Population (Persons in April)  2011  0 - 4 years        Male
# 10  Estimated Population (Persons in April)  2011  0 - 4 years        Male
# 11  Estimated Population (Persons in April)  2011  0 - 4 years        Male
# 12  Estimated Population (Persons in April)  2011  0 - 4 years        Male
# 13  Estimated Population (Persons in April)  2011  0 - 4 years        Male
# 14  Estimated Population (Persons in April)  2011  0 - 4 years        Male
# 15  Estimated Population (Persons in April)  2011  0 - 4 years        Male
# 16  Estimated Population (Persons in April)  2011  0 - 4 years        Male
# 17  Estimated Population (Persons in April)  2011  0 - 4 years        Male
# 18  Estimated Population (Persons in April)  2011  0 - 4 years      Female
# 19  Estimated Population (Persons in April)  2011  0 - 4 years      Female
# 20  Estimated Population (Persons in April)  2011  0 - 4 years      Female
# 21  Estimated Population (Persons in April)  2011  0 - 4 years      Female
# 22  Estimated Population (Persons in April)  2011  0 - 4 years      Female
# 23  Estimated Population (Persons in April)  2011  0 - 4 years      Female
# 24  Estimated Population (Persons in April)  2011  0 - 4 years      Female
# 25  Estimated Population (Persons in April)  2011  0 - 4 years      Female
# 26  Estimated Population (Persons in April)  2011  0 - 4 years      Female
# 27  Estimated Population (Persons in April)  2011  5 - 9 years  Both sexes
# 28  Estimated Population (Persons in April)  2011  5 - 9 years  Both sexes
# 29  Estimated Population (Persons in April)  2011  5 - 9 years  Both sexes
#
#         Region      UNIT  VALUE
# 0        State  Thousand  356.0
# 1       Border  Thousand   30.7
# 2         West  Thousand   32.6
# 3     Mid-West  Thousand   35.0
# 4   South-East  Thousand   32.0
# 5   South-West  Thousand   50.1
# 6       Dublin  Thousand   93.3
# 7     Mid-East  Thousand   58.5
# 8      Midland  Thousand   23.9
# 9        State  Thousand  182.0
# 10      Border  Thousand   15.8
# 11        West  Thousand   16.6
# 12    Mid-West  Thousand   18.0
# 13  South-East  Thousand   16.4
# 14  South-West  Thousand   25.5
# 15      Dublin  Thousand   47.6
# 16    Mid-East  Thousand   29.7
# 17     Midland  Thousand   12.3
# 18       State  Thousand  174.1
# 19      Border  Thousand   15.0
# 20        West  Thousand   16.0
# 21    Mid-West  Thousand   17.0
# 22  South-East  Thousand   15.6
# 23  South-West  Thousand   24.6
# 24      Dublin  Thousand   45.7
# 25    Mid-East  Thousand   28.7
# 26     Midland  Thousand   11.6
# 27       State  Thousand  319.6
# 28      Border  Thousand   28.4
# 29        West  Thousand   30.8

# %%
# Gives bottom 5 rows of dataset
population_dataframe.tail()
# Out:
#                               STATISTIC Label  Year Age Group     Sex  \
# 6664  Estimated Population (Persons in April)  2023  All ages  Female
# 6665  Estimated Population (Persons in April)  2023  All ages  Female
# 6666  Estimated Population (Persons in April)  2023  All ages  Female
# 6667  Estimated Population (Persons in April)  2023  All ages  Female
# 6668  Estimated Population (Persons in April)  2023  All ages  Female
#
#           Region      UNIT  VALUE
# 6664  South-East  Thousand  237.5
# 6665  South-West  Thousand  383.8
# 6666      Dublin  Thousand  765.6
# 6667    Mid-East  Thousand  391.3
# 6668     Midland  Thousand  163.2

# %%
# Gives random sample data
population_dataframe.sample(10)
# Out:
#                               STATISTIC Label  Year      Age Group  \
# 5163  Estimated Population (Persons in April)  2021    5 - 9 years
# 3009  Estimated Population (Persons in April)  2016  80 - 84 years
# 3109  Estimated Population (Persons in April)  2017    5 - 9 years
# 4690  Estimated Population (Persons in April)  2020  10 - 14 years
# 3892  Estimated Population (Persons in April)  2018  55 - 59 years
# 6221  Estimated Population (Persons in April)  2023  10 - 14 years
# 4183  Estimated Population (Persons in April)  2019  10 - 14 years
# 2163  Estimated Population (Persons in April)  2015  20 - 24 years
# 3930  Estimated Population (Persons in April)  2018  60 - 64 years
# 2657  Estimated Population (Persons in April)  2016  15 - 19 years
#
#              Sex      Region      UNIT  VALUE
# 5163  Both sexes      Dublin  Thousand   91.5
# 3009        Male    Mid-West  Thousand    3.9
# 3109  Both sexes  South-East  Thousand   32.7
# 4690      Female      Border  Thousand   15.3
# 3892  Both sexes  South-East  Thousand   26.6
# 6221        Male        West  Thousand   18.2
# 4183      Female    Mid-East  Thousand   28.1
# 2163  Both sexes    Mid-West  Thousand   27.7
# 3930        Male      Dublin  Thousand   29.8
# 2657        Male        West  Thousand   14.7

# %%
# rename columns name i.e no space should be in columns name
# use of try and except to handle if value list has not appropriate length for column
new_column_name = ['statistic_label','year','age_group','sex','region','unit','value']

def columns_dict(cols):
    new_col = {}
    
    if len(cols) == len(population_dataframe.columns):
        try:
            for i in range(len(cols)):
                new_col[population_dataframe.columns[i]] = cols[i]
        except:
            print("An error occurred while creating the column dictionary.")
    else:
        print(f"Your length of Population Dataframe {len(population_dataframe.columns)} != {len(new_column_name)} with length of New Column ")
    
    return new_col

col_dict = columns_dict(new_column_name)

# %% [markdown]
# ### Rename Column names

# %%
# inplace = True set the values permenantly so that we can use new columns name
population_dataframe.rename(columns=col_dict, inplace=True)

# %%
# drop column STATISTIC Label and Unit because it
population_dataframe.drop({'statistic_label', 'unit'}, axis=1, inplace=True)
population_dataframe.head()
# Out:
#    year    age_group         sex      region  value
# 0  2011  0 - 4 years  Both sexes       State  356.0
# 1  2011  0 - 4 years  Both sexes      Border   30.7
# 2  2011  0 - 4 years  Both sexes        West   32.6
# 3  2011  0 - 4 years  Both sexes    Mid-West   35.0
# 4  2011  0 - 4 years  Both sexes  South-East   32.0

# %%
# Checking the types of data
population_dataframe.dtypes
# Out:
# year           int64
# age_group     object
# sex           object
# region        object
# value        float64
# dtype: object

# %%
# isna().sum() provide sum of null value in each column in datasets
population_dataframe.isnull().sum()
# Out:
# year         0
# age_group    0
# sex          0
# region       0
# value        0
# dtype: int64

# %%
# info() provide information about datasets
population_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6669 entries, 0 to 6668
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       6669 non-null   int64
#  1   age_group  6669 non-null   object
#  2   sex        6669 non-null   object
#  3   region     6669 non-null   object
#  4   value      6669 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 260.6+ KB

# %%
population_dataframe.count()
# Out:
# year         6669
# age_group    6669
# sex          6669
# region       6669
# value        6669
# dtype: int64

# %%
# count duplicated value in dataset
population_dataframe.duplicated().sum()
# Out:
# 0

# %%
# describe() generate statistical descriptive value of dataset
population_dataframe.describe()
# Out:
#               year        value
# count  6669.000000  6669.000000
# mean   2017.000000    75.670460
# std       3.741938   281.512172
# min    2011.000000     1.200000
# 25%    2014.000000    12.500000
# 50%    2017.000000    20.700000
# 75%    2020.000000    42.200000
# max    2023.000000  5281.600000

# %%
# describe(include=object) generate statistical descriptive value for object datatype of dataset
population_dataframe.describe(include=object)
# Out:
#           age_group         sex region
# count          6669        6669   6669
# unique           19           3      9
# top     0 - 4 years  Both sexes  State
# freq            351        2223    741

# %%
# It return all unique value of series object
population_dataframe['age_group'].unique()
# Out:
# array(['0 - 4 years', '5 - 9 years', '10 - 14 years', '15 - 19 years',
#        '20 - 24 years', '25 - 29 years', '30 - 34 years', '35 - 39 years',
#        '40 - 44 years', '45 - 49 years', '50 - 54 years', '55 - 59 years',
#        '60 - 64 years', '65 - 69 years', '70 - 74 years', '75 - 79 years',
#        '80 - 84 years', '85 years and over', 'All ages'], dtype=object)

# %%
# It return all unique value of series object
population_dataframe['year'].unique()
# Out:
# array([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022, 2023])

# %% [markdown]
# #### Remove State from observation

# %%
# Remove State observation from region because state is sum of all other 8 region population

new_population_dataframe = population_dataframe.loc[population_dataframe['region'] != 'State']
new_population_dataframe.head()
# Out:
#    year    age_group         sex      region  value
# 1  2011  0 - 4 years  Both sexes      Border   30.7
# 2  2011  0 - 4 years  Both sexes        West   32.6
# 3  2011  0 - 4 years  Both sexes    Mid-West   35.0
# 4  2011  0 - 4 years  Both sexes  South-East   32.0
# 5  2011  0 - 4 years  Both sexes  South-West   50.1

# %%
# Unique region 
new_population_dataframe['region'].unique()
# Out:
# array(['Border', 'West', 'Mid-West', 'South-East', 'South-West', 'Dublin',
#        'Mid-East', 'Midland'], dtype=object)

# %%
# Unique sex 
new_population_dataframe['sex'].unique()
# Out:
# array(['Both sexes', 'Male', 'Female'], dtype=object)

# %%
# Unique age_group
new_population_dataframe['age_group'].unique()
# Out:
# array(['0 - 4 years', '5 - 9 years', '10 - 14 years', '15 - 19 years',
#        '20 - 24 years', '25 - 29 years', '30 - 34 years', '35 - 39 years',
#        '40 - 44 years', '45 - 49 years', '50 - 54 years', '55 - 59 years',
#        '60 - 64 years', '65 - 69 years', '70 - 74 years', '75 - 79 years',
#        '80 - 84 years', '85 years and over', 'All ages'], dtype=object)

# %% [markdown]
# #### Remove Both sexes and All age group from observation

# %%
# Remove Both sexes observation from sex column and All ages observation from age_group column because both sexes is sum of male and female population and all ages are sum of rest of categorical age

new_population_dataframe = new_population_dataframe.loc[(new_population_dataframe['sex'] != 'Both sexes') & (new_population_dataframe['age_group'] != 'All ages')]
new_population_dataframe.reset_index(drop=True, inplace=True)
new_population_dataframe.tail(5)
# Out:
#       year          age_group     sex      region  value
# 3739  2023  85 years and over  Female  South-East    5.0
# 3740  2023  85 years and over  Female  South-West    8.1
# 3741  2023  85 years and over  Female      Dublin   15.5
# 3742  2023  85 years and over  Female    Mid-East    6.0
# 3743  2023  85 years and over  Female     Midland    3.0

# %%
# Boxplot helps to identify outliers
def plot_boxplot(col_name):
    plt.figure(figsize=(8,6))
    plt.boxplot(x=col_name);

# %%
# call plot_boxplot for year column, Hence there are no outliers
plot_boxplot(new_population_dataframe['year'])

# %%
# call plot_boxplot function for value column, Hence there are outliers
plot_boxplot(new_population_dataframe['value'])

# %%
# Function to remove outliers from datasets by using IQR (Interquartile Range)

def remove_outliers(col_name):
    Q1 = new_population_dataframe[col_name].quantile(0.25)
    Q3 = new_population_dataframe[col_name].quantile(0.75)
    IQR = Q3-Q1 
    lower_limit = Q1 - 1.5*IQR
    upper_limit = Q3 + 1.5*IQR
    print('IQR',IQR)
    print('lower_limit',lower_limit)
    print('upper_limit',upper_limit)
    new_data = new_population_dataframe[(new_population_dataframe['value'] > lower_limit) & (new_population_dataframe['value'] < upper_limit)]
    return new_data
    
newdata_no_outliers = remove_outliers('value')

plot_boxplot(newdata_no_outliers['value'])
# Out:
# IQR 9.8
# lower_limit -4.500000000000002
# upper_limit 34.7

# %%
# plt.figure(figsize=(8,6))
# # correlation = population_dataframe.corr()
# correlation = newdata_no_outliers.corr(numeric_only=True)
# plt.heatmap(correlation, annot=True, fmt='.2f', linewidths=2, cmap="BrBG")
# correlation

# %%
newdata_no_outliers.describe()
# Out:
#               year        value
# count  3441.000000  3441.000000
# mean   2016.977332    14.151148
# std       3.742366     6.793485
# min    2011.000000     1.200000
# 25%    2014.000000     9.700000
# 50%    2017.000000    13.800000
# 75%    2020.000000    17.300000
# max    2023.000000    34.600000

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.scatter(newdata_no_outliers["year"], newdata_no_outliers["value"])
# ax.scatter(population_dataframe["year"], population_dataframe["value"])

ax.set_xlabel("Years")
ax.set_ylabel("Value in thousands")
plt.show()

# %%
newdata_no_outliers.describe()
# Out:
#               year        value
# count  3441.000000  3441.000000
# mean   2016.977332    14.151148
# std       3.742366     6.793485
# min    2011.000000     1.200000
# 25%    2014.000000     9.700000
# 50%    2017.000000    13.800000
# 75%    2020.000000    17.300000
# max    2023.000000    34.600000

# %%
# Histplot explain distribution of data i.e Symmetric distribution  data
# plt.histplot(data=newdata_no_outliers, x='value', kde=True, bins=50);

# %% [markdown]
# #### Calculate Skewness for distribution of data

# %%
# best skew value should be -3 to +3
# skew_value = stats.skew(newdata_no_outliers['value'], axis=0, bias=True)
# print('Skew Value',skew_value)

# %% [markdown]
# #### Calculate kurtosis for distribution of data

# %%
# # best kurtosis value should be -10 to +10
# kurtosis_value = stats.kurtosis(newdata_no_outliers['value'], axis=0, bias=True)
# print('kurtosis Value',kurtosis_value)

# %%
newdata_no_outliers.describe(include=object)
# Out:
#                 age_group   sex  region
# count                3441  3441    3441
# unique                 18     2       8
# top     85 years and over  Male  Border
# freq                  208  1723     468

# %%
newdata_no_outliers['age_group'].unique()
# Out:
# array(['0 - 4 years', '5 - 9 years', '10 - 14 years', '15 - 19 years',
#        '20 - 24 years', '25 - 29 years', '30 - 34 years', '35 - 39 years',
#        '40 - 44 years', '45 - 49 years', '50 - 54 years', '55 - 59 years',
#        '60 - 64 years', '65 - 69 years', '70 - 74 years', '75 - 79 years',
#        '80 - 84 years', '85 years and over'], dtype=object)

# %% [markdown]
# ### Total population by year of all states from 2011-2023

# %%
all_age_bt_sex_state_df = population_dataframe.loc[(population_dataframe['sex'] == 'Both sexes') & (population_dataframe['region'] == 'State') & (population_dataframe['age_group'] == 'All ages')].reset_index(drop=True)

# %%
# Statistical value for bar graph year and population
all_age_bt_sex_state_df[['year','value']]
# Out:
#     year   value
# 0   2011  4574.9
# 1   2012  4593.7
# 2   2013  4614.7
# 3   2014  4645.4
# 4   2015  4687.8
# 5   2016  4739.6
# 6   2017  4810.9
# 7   2018  4884.9
# 8   2019  4958.5
# 9   2020  5029.9
# 10  2021  5074.7
# 11  2022  5184.0
# 12  2023  5281.6

# %% [markdown]
# #### Statistical value  for bar graph

# %%
print(f"Max: {all_age_bt_sex_state_df[['year','value']].max()},  Min: {all_age_bt_sex_state_df[['year','value']].min()}, Mean: {all_age_bt_sex_state_df[['year','value']].mean()} ")
# Out:
# Max: year     2023.0
# value    5281.6
# dtype: float64,  Min: year     2011.0
# value    4574.9
# dtype: float64, Mean: year     2017.000000
# value    4852.353846
# dtype: float64

# %%
#Bar graph to compare population by year 2011-2023 
plt.bar(all_age_bt_sex_state_df['year'], all_age_bt_sex_state_df['value'])
plt.title("Population of Ireland By Years")
plt.ylabel("Population in thousands")
plt.xlabel("Years")
plt.show()

# %% [markdown]
# ### Child population age 0-4 years, both sex, all states

# %%
age04_bt_sex_state_df = population_dataframe.loc[(population_dataframe['sex'] == 'Both sexes') & (population_dataframe['region'] == 'State') & (population_dataframe['age_group'] == '0 - 4 years')].reset_index(drop=True)
age04_bt_sex_state_df
# Out:
#     year    age_group         sex region  value
# 0   2011  0 - 4 years  Both sexes  State  356.0
# 1   2012  0 - 4 years  Both sexes  State  358.2
# 2   2013  0 - 4 years  Both sexes  State  353.0
# 3   2014  0 - 4 years  Both sexes  State  345.4
# 4   2015  0 - 4 years  Both sexes  State  337.9
# 5   2016  0 - 4 years  Both sexes  State  331.4
# 6   2017  0 - 4 years  Both sexes  State  325.0
# 7   2018  0 - 4 years  Both sexes  State  320.0
# 8   2019  0 - 4 years  Both sexes  State  315.0
# 9   2020  0 - 4 years  Both sexes  State  308.7
# 10  2021  0 - 4 years  Both sexes  State  300.9
# 11  2022  0 - 4 years  Both sexes  State  295.8
# 12  2023  0 - 4 years  Both sexes  State  293.8

# %%
#Bar graph to compare population by year 2011-2023 
plt.plot(age04_bt_sex_state_df['year'], age04_bt_sex_state_df['value'])
plt.title("Population of child from age 0-4 years")
plt.ylabel("Population in thousands")
plt.xlabel("Years")
plt.show()

# why child birth is decreasing each year -> research

# %% [markdown]
# ###  Older Adults Population age 85 years and above , both sex, all states

# %%
age85_above_bt_sex_state_df = population_dataframe.loc[(population_dataframe['sex'] == 'Both sexes') & (population_dataframe['region'] == 'State') & (population_dataframe['age_group'] == '85 years and over')].reset_index(drop=True)
age85_above_bt_sex_state_df
# Out:
#     year          age_group         sex region  value
# 0   2011  85 years and over  Both sexes  State   58.2
# 1   2012  85 years and over  Both sexes  State   59.8
# 2   2013  85 years and over  Both sexes  State   60.7
# 3   2014  85 years and over  Both sexes  State   62.7
# 4   2015  85 years and over  Both sexes  State   64.9
# 5   2016  85 years and over  Both sexes  State   67.3
# 6   2017  85 years and over  Both sexes  State   69.1
# 7   2018  85 years and over  Both sexes  State   71.8
# 8   2019  85 years and over  Both sexes  State   74.1
# 9   2020  85 years and over  Both sexes  State   75.6
# 10  2021  85 years and over  Both sexes  State   77.5
# 11  2022  85 years and over  Both sexes  State   84.4
# 12  2023  85 years and over  Both sexes  State   87.1

# %%
#Bar graph to compare population by year 2011-2023 
plt.plot(age85_above_bt_sex_state_df['year'], age85_above_bt_sex_state_df['value'])
plt.title("Population age 80 and above")
plt.ylabel("Population in thousands")
plt.xlabel("Years")
plt.show()

# %% [markdown]
# #### Working population in ireland age 15-64

# %%
population_dataframe
# Out:
#       year          age_group         sex      region   value
# 0     2011        0 - 4 years  Both sexes       State   356.0
# 1     2011        0 - 4 years  Both sexes      Border    30.7
# 2     2011        0 - 4 years  Both sexes        West    32.6
# 3     2011        0 - 4 years  Both sexes    Mid-West    35.0
# 4     2011        0 - 4 years  Both sexes  South-East    32.0
# 5     2011        0 - 4 years  Both sexes  South-West    50.1
# 6     2011        0 - 4 years  Both sexes      Dublin    93.3
# 7     2011        0 - 4 years  Both sexes    Mid-East    58.5
# 8     2011        0 - 4 years  Both sexes     Midland    23.9
# 9     2011        0 - 4 years        Male       State   182.0
# 10    2011        0 - 4 years        Male      Border    15.8
# 11    2011        0 - 4 years        Male        West    16.6
# 12    2011        0 - 4 years        Male    Mid-West    18.0
# 13    2011        0 - 4 years        Male  South-East    16.4
# 14    2011        0 - 4 years        Male  South-West    25.5
# 15    2011        0 - 4 years        Male      Dublin    47.6
# 16    2011        0 - 4 years        Male    Mid-East    29.7
# 17    2011        0 - 4 years        Male     Midland    12.3
# 18    2011        0 - 4 years      Female       State   174.1
# 19    2011        0 - 4 years      Female      Border    15.0
# 20    2011        0 - 4 years      Female        West    16.0
# 21    2011        0 - 4 years      Female    Mid-West    17.0
# 22    2011        0 - 4 years      Female  South-East    15.6
# 23    2011        0 - 4 years      Female  South-West    24.6
# 24    2011        0 - 4 years      Female      Dublin    45.7
# 25    2011        0 - 4 years      Female    Mid-East    28.7
# 26    2011        0 - 4 years      Female     Midland    11.6
# 27    2011        5 - 9 years  Both sexes       State   319.6
# 28    2011        5 - 9 years  Both sexes      Border    28.4
# 29    2011        5 - 9 years  Both sexes        West    30.8
# 258   2011      45 - 49 years        Male      Dublin    38.3
# 259   2011      45 - 49 years        Male    Mid-East    22.8
# 260   2011      45 - 49 years        Male     Midland     9.5
# 261   2011      45 - 49 years      Female       State   152.9
# 262   2011      45 - 49 years      Female      Border    13.0
# 263   2011      45 - 49 years      Female        West    14.6
# 264   2011      45 - 49 years      Female    Mid-West    15.7
# 265   2011      45 - 49 years      Female  South-East    14.1
# 266   2011      45 - 49 years      Female  South-West    22.6
# 267   2011      45 - 49 years      Female      Dublin    41.1
# 268   2011      45 - 49 years      Female    Mid-East    22.5
# 269   2011      45 - 49 years      Female     Midland     9.3
# 270   2011      50 - 54 years  Both sexes       State   273.7
# 271   2011      50 - 54 years  Both sexes      Border    24.0
# 272   2011      50 - 54 years  Both sexes        West    27.7
# 273   2011      50 - 54 years  Both sexes    Mid-West    29.2
# 274   2011      50 - 54 years  Both sexes  South-East    25.3
# 275   2011      50 - 54 years  Both sexes  South-West    40.9
# 276   2011      50 - 54 years  Both sexes      Dublin    71.4
# 277   2011      50 - 54 years  Both sexes    Mid-East    38.2
# 278   2011      50 - 54 years  Both sexes     Midland    17.0
# 279   2011      50 - 54 years        Male       State   136.7
# 280   2011      50 - 54 years        Male      Border    12.1
# 281   2011      50 - 54 years        Male        West    13.9
# 282   2011      50 - 54 years        Male    Mid-West    14.9
# 283   2011      50 - 54 years        Male  South-East    12.7
# 284   2011      50 - 54 years        Male  South-West    20.6
# 285   2011      50 - 54 years        Male      Dublin    34.6
# 286   2011      50 - 54 years        Male    Mid-East    19.2
# 287   2011      50 - 54 years        Male     Midland     8.7
# 288   2011      50 - 54 years      Female       State   137.1
# 289   2011      50 - 54 years      Female      Border    12.0
# 290   2011      50 - 54 years      Female        West    13.8
# 291   2011      50 - 54 years      Female    Mid-West    14.3
# 292   2011      50 - 54 years      Female  South-East    12.6
# 293   2011      50 - 54 years      Female  South-West    20.3
# 294   2011      50 - 54 years      Female      Dublin    36.9
# 295   2011      50 - 54 years      Female    Mid-East    19.0
# 296   2011      50 - 54 years      Female     Midland     8.2
# 297   2011      55 - 59 years  Both sexes       State   243.4
# 298   2011      55 - 59 years  Both sexes      Border    22.0
# 299   2011      55 - 59 years  Both sexes        West    25.3
# 300   2011      55 - 59 years  Both sexes    Mid-West    26.6
# 301   2011      55 - 59 years  Both sexes  South-East    22.5
# 302   2011      55 - 59 years  Both sexes  South-West    36.7
# 303   2011      55 - 59 years  Both sexes      Dublin    62.4
# 304   2011      55 - 59 years  Both sexes    Mid-East    33.0
# 305   2011      55 - 59 years  Both sexes     Midland    14.9
# 306   2011      55 - 59 years        Male       State   121.8
# 307   2011      55 - 59 years        Male      Border    11.3
# 308   2011      55 - 59 years        Male        West    12.8
# 309   2011      55 - 59 years        Male    Mid-West    13.6
# 310   2011      55 - 59 years        Male  South-East    11.4
# 311   2011      55 - 59 years        Male  South-West    18.6
# 312   2011      55 - 59 years        Male      Dublin    30.0
# 313   2011      55 - 59 years        Male    Mid-East    16.5
# 314   2011      55 - 59 years        Male     Midland     7.7
# 315   2011      55 - 59 years      Female       State   121.6
# 316   2011      55 - 59 years      Female      Border    10.7
# 317   2011      55 - 59 years      Female        West    12.4
# 318   2011      55 - 59 years      Female    Mid-West    13.1
# 319   2011      55 - 59 years      Female  South-East    11.1
# 320   2011      55 - 59 years      Female  South-West    18.2
# 321   2011      55 - 59 years      Female      Dublin    32.5
# 322   2011      55 - 59 years      Female    Mid-East    16.4
# 323   2011      55 - 59 years      Female     Midland     7.2
# 324   2011      60 - 64 years  Both sexes       State   217.1
# 325   2011      60 - 64 years  Both sexes      Border    20.2
# 326   2011      60 - 64 years  Both sexes        West    22.5
# 327   2011      60 - 64 years  Both sexes    Mid-West    24.4
# 328   2011      60 - 64 years  Both sexes  South-East    20.2
# 329   2011      60 - 64 years  Both sexes  South-West    33.0
# 330   2011      60 - 64 years  Both sexes      Dublin    55.2
# 331   2011      60 - 64 years  Both sexes    Mid-East    28.7
# 332   2011      60 - 64 years  Both sexes     Midland    13.0
# 333   2011      60 - 64 years        Male       State   109.2
# 334   2011      60 - 64 years        Male      Border    10.4
# 335   2011      60 - 64 years        Male        West    11.6
# 336   2011      60 - 64 years        Male    Mid-West    12.3
# 337   2011      60 - 64 years        Male  South-East    10.3
# 338   2011      60 - 64 years        Male  South-West    16.8
# 339   2011      60 - 64 years        Male      Dublin    26.7
# 340   2011      60 - 64 years        Male    Mid-East    14.5
# 341   2011      60 - 64 years        Male     Midland     6.6
# 342   2011      60 - 64 years      Female       State   107.9
# 343   2011      60 - 64 years      Female      Border     9.8
# 344   2011      60 - 64 years      Female        West    10.9
# 345   2011      60 - 64 years      Female    Mid-West    12.0
# 346   2011      60 - 64 years      Female  South-East     9.9
# 347   2011      60 - 64 years      Female  South-West    16.2
# 348   2011      60 - 64 years      Female      Dublin    28.5
# 349   2011      60 - 64 years      Female    Mid-East    14.2
# 350   2011      60 - 64 years      Female     Midland     6.4
# 351   2011      65 - 69 years  Both sexes       State   172.1
# 352   2011      65 - 69 years  Both sexes      Border    16.1
# 353   2011      65 - 69 years  Both sexes        West    17.9
# 354   2011      65 - 69 years  Both sexes    Mid-West    19.2
# 355   2011      65 - 69 years  Both sexes  South-East    16.7
# 356   2011      65 - 69 years  Both sexes  South-West    26.4
# 357   2011      65 - 69 years  Both sexes      Dublin    43.3
# 358   2011      65 - 69 years  Both sexes    Mid-East    22.2
# 359   2011      65 - 69 years  Both sexes     Midland    10.3
# 360   2011      65 - 69 years        Male       State    85.6
# 361   2011      65 - 69 years        Male      Border     8.4
# 362   2011      65 - 69 years        Male        West     9.2
# 363   2011      65 - 69 years        Male    Mid-West     9.6
# 364   2011      65 - 69 years        Male  South-East     8.3
# 365   2011      65 - 69 years        Male  South-West    13.2
# 366   2011      65 - 69 years        Male      Dublin    20.5
# 367   2011      65 - 69 years        Male    Mid-East    11.2
# 368   2011      65 - 69 years        Male     Midland     5.2
# 369   2011      65 - 69 years      Female       State    86.5
# 370   2011      65 - 69 years      Female      Border     7.7
# 371   2011      65 - 69 years      Female        West     8.7
# 372   2011      65 - 69 years      Female    Mid-West     9.6
# 373   2011      65 - 69 years      Female  South-East     8.3
# 374   2011      65 - 69 years      Female  South-West    13.3
# 375   2011      65 - 69 years      Female      Dublin    22.8
# 376   2011      65 - 69 years      Female    Mid-East    11.0
# 377   2011      65 - 69 years      Female     Midland     5.1
# 378   2011      70 - 74 years  Both sexes       State   130.1
# 379   2011      70 - 74 years  Both sexes      Border    12.1
# 380   2011      70 - 74 years  Both sexes        West    13.4
# 381   2011      70 - 74 years  Both sexes    Mid-West    14.4
# 382   2011      70 - 74 years  Both sexes  South-East    12.6
# 383   2011      70 - 74 years  Both sexes  South-West    20.1
# 384   2011      70 - 74 years  Both sexes      Dublin    34.8
# 385   2011      70 - 74 years  Both sexes    Mid-East    15.0
# 386   2011      70 - 74 years  Both sexes     Midland     7.6
# 387   2011      70 - 74 years        Male       State    62.9
# 388   2011      70 - 74 years        Male      Border     6.0
# 389   2011      70 - 74 years        Male        West     6.8
# 390   2011      70 - 74 years        Male    Mid-West     7.1
# 391   2011      70 - 74 years        Male  South-East     6.3
# 392   2011      70 - 74 years        Male  South-West     9.7
# 393   2011      70 - 74 years        Male      Dublin    15.9
# 394   2011      70 - 74 years        Male    Mid-East     7.4
# 395   2011      70 - 74 years        Male     Midland     3.8
# 396   2011      70 - 74 years      Female       State    67.2
# 397   2011      70 - 74 years      Female      Border     6.1
# 398   2011      70 - 74 years      Female        West     6.6
# 399   2011      70 - 74 years      Female    Mid-West     7.3
# 400   2011      70 - 74 years      Female  South-East     6.3
# 401   2011      70 - 74 years      Female  South-West    10.4
# 402   2011      70 - 74 years      Female      Dublin    18.9
# 403   2011      70 - 74 years      Female    Mid-East     7.7
# 404   2011      70 - 74 years      Female     Midland     3.9
# 405   2011      75 - 79 years  Both sexes       State   101.4
# 406   2011      75 - 79 years  Both sexes      Border     9.7
# 407   2011      75 - 79 years  Both sexes        West    10.8
# 408   2011      75 - 79 years  Both sexes    Mid-West    11.2
# 409   2011      75 - 79 years  Both sexes  South-East     9.7
# 410   2011      75 - 79 years  Both sexes  South-West    15.8
# 411   2011      75 - 79 years  Both sexes      Dublin    27.2
# 412   2011      75 - 79 years  Both sexes    Mid-East    10.8
# 413   2011      75 - 79 years  Both sexes     Midland     6.1
# 414   2011      75 - 79 years        Male       State    46.3
# 415   2011      75 - 79 years        Male      Border     4.7
# 416   2011      75 - 79 years        Male        West     5.2
# 417   2011      75 - 79 years        Male    Mid-West     5.2
# 418   2011      75 - 79 years        Male  South-East     4.5
# 419   2011      75 - 79 years        Male  South-West     7.2
# 420   2011      75 - 79 years        Male      Dublin    11.7
# 421   2011      75 - 79 years        Male    Mid-East     5.0
# 422   2011      75 - 79 years        Male     Midland     2.9
# 423   2011      75 - 79 years      Female       State    55.0
# 424   2011      75 - 79 years      Female      Border     5.1
# 425   2011      75 - 79 years      Female        West     5.6
# 426   2011      75 - 79 years      Female    Mid-West     5.9
# 427   2011      75 - 79 years      Female  South-East     5.1
# 428   2011      75 - 79 years      Female  South-West     8.6
# 429   2011      75 - 79 years      Female      Dublin    15.6
# 430   2011      75 - 79 years      Female    Mid-East     5.8
# 431   2011      75 - 79 years      Female     Midland     3.2
# 432   2011      80 - 84 years  Both sexes       State    69.8
# 433   2011      80 - 84 years  Both sexes      Border     6.9
# 434   2011      80 - 84 years  Both sexes        West     7.8
# 435   2011      80 - 84 years  Both sexes    Mid-West     7.8
# 436   2011      80 - 84 years  Both sexes  South-East     6.3
# 437   2011      80 - 84 years  Both sexes  South-West    10.9
# 438   2011      80 - 84 years  Both sexes      Dublin    18.7
# 439   2011      80 - 84 years  Both sexes    Mid-East     7.2
# 440   2011      80 - 84 years  Both sexes     Midland     4.2
# 441   2011      80 - 84 years        Male       State    28.3
# 442   2011      80 - 84 years        Male      Border     2.9
# 443   2011      80 - 84 years        Male        West     3.3
# 444   2011      80 - 84 years        Male    Mid-West     3.2
# 445   2011      80 - 84 years        Male  South-East     2.7
# 446   2011      80 - 84 years        Male  South-West     4.4
# 447   2011      80 - 84 years        Male      Dublin     7.0
# 448   2011      80 - 84 years        Male    Mid-East     2.9
# 449   2011      80 - 84 years        Male     Midland     1.8
# 450   2011      80 - 84 years      Female       State    41.5
# 451   2011      80 - 84 years      Female      Border     3.9
# 452   2011      80 - 84 years      Female        West     4.5
# 453   2011      80 - 84 years      Female    Mid-West     4.5
# 454   2011      80 - 84 years      Female  South-East     3.6
# 455   2011      80 - 84 years      Female  South-West     6.4
# 456   2011      80 - 84 years      Female      Dublin    11.7
# 457   2011      80 - 84 years      Female    Mid-East     4.3
# 458   2011      80 - 84 years      Female     Midland     2.5
# 459   2011  85 years and over  Both sexes       State    58.2
# 460   2011  85 years and over  Both sexes      Border     6.3
# 461   2011  85 years and over  Both sexes        West     7.0
# 462   2011  85 years and over  Both sexes    Mid-West     6.3
# 463   2011  85 years and over  Both sexes  South-East     5.3
# 464   2011  85 years and over  Both sexes  South-West     8.9
# 465   2011  85 years and over  Both sexes      Dublin    14.6
# 466   2011  85 years and over  Both sexes    Mid-East     6.3
# 467   2011  85 years and over  Both sexes     Midland     3.5
# 468   2011  85 years and over        Male       State    18.4
# 469   2011  85 years and over        Male      Border     2.1
# 470   2011  85 years and over        Male        West     2.3
# 471   2011  85 years and over        Male    Mid-West     2.0
# 472   2011  85 years and over        Male  South-East     1.7
# 473   2011  85 years and over        Male  South-West     2.8
# 474   2011  85 years and over        Male      Dublin     4.4
# 475   2011  85 years and over        Male    Mid-East     1.9
# 476   2011  85 years and over        Male     Midland     1.2
# 477   2011  85 years and over      Female       State    39.8
# 478   2011  85 years and over      Female      Border     4.2
# 479   2011  85 years and over      Female        West     4.7
# 480   2011  85 years and over      Female    Mid-West     4.3
# 481   2011  85 years and over      Female  South-East     3.5
# 482   2011  85 years and over      Female  South-West     6.1
# 483   2011  85 years and over      Female      Dublin    10.3
# 484   2011  85 years and over      Female    Mid-East     4.4
# 485   2011  85 years and over      Female     Midland     2.3
# 486   2011           All ages  Both sexes       State  4574.9
# 487   2011           All ages  Both sexes      Border   391.9
# 488   2011           All ages  Both sexes        West   440.8
# 489   2011           All ages  Both sexes    Mid-West   466.8
# 490   2011           All ages  Both sexes  South-East   410.3
# 491   2011           All ages  Both sexes  South-West   662.3
# 492   2011           All ages  Both sexes      Dublin  1261.5
# 493   2011           All ages  Both sexes    Mid-East   657.4
# 494   2011           All ages  Both sexes     Midland   283.8
# 495   2011           All ages        Male       State  2270.5
# 496   2011           All ages        Male      Border   197.0
# 497   2011           All ages        Male        West   220.5
# 498   2011           All ages        Male    Mid-West   233.7
# 499   2011           All ages        Male  South-East   204.7
# 500   2011           All ages        Male  South-West   329.6
# 501   2011           All ages        Male      Dublin   615.4
# 502   2011           All ages        Male    Mid-East   327.3
# 503   2011           All ages        Male     Midland   142.4
# 504   2011           All ages      Female       State  2304.4
# 505   2011           All ages      Female      Border   194.9
# 506   2011           All ages      Female        West   220.3
# 507   2011           All ages      Female    Mid-West   233.2
# 508   2011           All ages      Female  South-East   205.6
# 509   2011           All ages      Female  South-West   332.7
# 510   2011           All ages      Female      Dublin   646.2
# 511   2011           All ages      Female    Mid-East   330.1
# 512   2011           All ages      Female     Midland   141.4
# 513   2012        0 - 4 years  Both sexes       State   358.2
# 514   2012        0 - 4 years  Both sexes      Border    30.7
# 515   2012        0 - 4 years  Both sexes        West    32.8
# 516   2012        0 - 4 years  Both sexes    Mid-West    35.1
# 517   2012        0 - 4 years  Both sexes  South-East    32.0
# 518   2012        0 - 4 years  Both sexes  South-West    50.5
# 519   2012        0 - 4 years  Both sexes      Dublin    94.0
# 520   2012        0 - 4 years  Both sexes    Mid-East    58.6
# 521   2012        0 - 4 years  Both sexes     Midland    24.4
# 522   2012        0 - 4 years        Male       State   182.7
# 523   2012        0 - 4 years        Male      Border    15.8
# 524   2012        0 - 4 years        Male        West    16.8
# 525   2012        0 - 4 years        Male    Mid-West    18.0
# 526   2012        0 - 4 years        Male  South-East    16.5
# 527   2012        0 - 4 years        Male  South-West    25.6
# 528   2012        0 - 4 years        Male      Dublin    47.8
# 529   2012        0 - 4 years        Male    Mid-East    29.7
# 530   2012        0 - 4 years        Male     Midland    12.5
# 531   2012        0 - 4 years      Female       State   175.4
# 532   2012        0 - 4 years      Female      Border    14.9
# 533   2012        0 - 4 years      Female        West    16.0
# 534   2012        0 - 4 years      Female    Mid-West    17.1
# 535   2012        0 - 4 years      Female  South-East    15.5
# 536   2012        0 - 4 years      Female  South-West    24.9
# 537   2012        0 - 4 years      Female      Dublin    46.2
# 538   2012        0 - 4 years      Female    Mid-East    28.9
# 539   2012        0 - 4 years      Female     Midland    11.9
# 540   2012        5 - 9 years  Both sexes       State   325.3
# 541   2012        5 - 9 years  Both sexes      Border    28.7
# 542   2012        5 - 9 years  Both sexes        West    30.9
# 543   2012        5 - 9 years  Both sexes    Mid-West    33.0
# 544   2012        5 - 9 years  Both sexes  South-East    30.4
# 545   2012        5 - 9 years  Both sexes  South-West    45.9
# 546   2012        5 - 9 years  Both sexes      Dublin    80.6
# 547   2012        5 - 9 years  Both sexes    Mid-East    53.3
# 548   2012        5 - 9 years  Both sexes     Midland    22.5
# 549   2012        5 - 9 years        Male       State   166.4
# 550   2012        5 - 9 years        Male      Border    14.9
# 551   2012        5 - 9 years        Male        West    15.8
# 552   2012        5 - 9 years        Male    Mid-West    16.7
# 553   2012        5 - 9 years        Male  South-East    15.5
# 554   2012        5 - 9 years        Male  South-West    23.6
# 555   2012        5 - 9 years        Male      Dublin    40.9
# 556   2012        5 - 9 years        Male    Mid-East    27.4
# 557   2012        5 - 9 years        Male     Midland    11.5
# 558   2012        5 - 9 years      Female       State   159.0
# 559   2012        5 - 9 years      Female      Border    13.9
# 560   2012        5 - 9 years      Female        West    15.1
# 561   2012        5 - 9 years      Female    Mid-West    16.3
# 562   2012        5 - 9 years      Female  South-East    14.8
# 563   2012        5 - 9 years      Female  South-West    22.3
# 564   2012        5 - 9 years      Female      Dublin    39.7
# 565   2012        5 - 9 years      Female    Mid-East    25.9
# 566   2012        5 - 9 years      Female     Midland    11.0
# 567   2012      10 - 14 years  Both sexes       State   304.5
# 568   2012      10 - 14 years  Both sexes      Border    28.0
# 569   2012      10 - 14 years  Both sexes        West    29.2
# 570   2012      10 - 14 years  Both sexes    Mid-West    32.0
# 571   2012      10 - 14 years  Both sexes  South-East    29.0
# 572   2012      10 - 14 years  Both sexes  South-West    43.6
# 573   2012      10 - 14 years  Both sexes      Dublin    73.6
# 574   2012      10 - 14 years  Both sexes    Mid-East    48.1
# 575   2012      10 - 14 years  Both sexes     Midland    21.1
# 576   2012      10 - 14 years        Male       State   156.3
# 577   2012      10 - 14 years        Male      Border    14.5
# 578   2012      10 - 14 years        Male        West    14.9
# 579   2012      10 - 14 years        Male    Mid-West    16.2
# 580   2012      10 - 14 years        Male  South-East    14.8
# 581   2012      10 - 14 years        Male  South-West    22.3
# 582   2012      10 - 14 years        Male      Dublin    37.8
# 583   2012      10 - 14 years        Male    Mid-East    25.0
# 584   2012      10 - 14 years        Male     Midland    10.8
# 585   2012      10 - 14 years      Female       State   148.3
# 586   2012      10 - 14 years      Female      Border    13.6
# 587   2012      10 - 14 years      Female        West    14.3
# 588   2012      10 - 14 years      Female    Mid-West    15.8
# 589   2012      10 - 14 years      Female  South-East    14.1
# 590   2012      10 - 14 years      Female  South-West    21.3
# 591   2012      10 - 14 years      Female      Dublin    35.7
# 592   2012      10 - 14 years      Female    Mid-East    23.1
# 593   2012      10 - 14 years      Female     Midland    10.3
# 594   2012      15 - 19 years  Both sexes       State   281.5
# 595   2012      15 - 19 years  Both sexes      Border    26.2
# 596   2012      15 - 19 years  Both sexes        West    27.6
# 597   2012      15 - 19 years  Both sexes    Mid-West    30.5
# 598   2012      15 - 19 years  Both sexes  South-East    26.3
# 599   2012      15 - 19 years  Both sexes  South-West    41.4
# 600   2012      15 - 19 years  Both sexes      Dublin    70.0
# 601   2012      15 - 19 years  Both sexes    Mid-East    41.3
# 602   2012      15 - 19 years  Both sexes     Midland    18.1
# 603   2012      15 - 19 years        Male       State   144.3
# 604   2012      15 - 19 years        Male      Border    13.6
# 605   2012      15 - 19 years        Male        West    14.1
# 606   2012      15 - 19 years        Male    Mid-West    15.8
# 607   2012      15 - 19 years        Male  South-East    13.4
# 608   2012      15 - 19 years        Male  South-West    21.2
# 609   2012      15 - 19 years        Male      Dublin    36.0
# 610   2012      15 - 19 years        Male    Mid-East    21.1
# 611   2012      15 - 19 years        Male     Midland     9.1
# 612   2012      15 - 19 years      Female       State   137.2
# 613   2012      15 - 19 years      Female      Border    12.5
# 614   2012      15 - 19 years      Female        West    13.4
# 615   2012      15 - 19 years      Female    Mid-West    14.7
# 616   2012      15 - 19 years      Female  South-East    12.9
# 617   2012      15 - 19 years      Female  South-West    20.2
# 618   2012      15 - 19 years      Female      Dublin    34.0
# 619   2012      15 - 19 years      Female    Mid-East    20.2
# 620   2012      15 - 19 years      Female     Midland     9.1
# 621   2012      20 - 24 years  Both sexes       State   285.1
# 622   2012      20 - 24 years  Both sexes      Border    22.1
# 623   2012      20 - 24 years  Both sexes        West    25.9
# 624   2012      20 - 24 years  Both sexes    Mid-West    29.4
# 625   2012      20 - 24 years  Both sexes  South-East    24.0
# 626   2012      20 - 24 years  Both sexes  South-West    41.4
# 627   2012      20 - 24 years  Both sexes      Dublin    89.1
# 628   2012      20 - 24 years  Both sexes    Mid-East    37.3
# 629   2012      20 - 24 years  Both sexes     Midland    15.8
# 630   2012      20 - 24 years        Male       State   141.5
# 631   2012      20 - 24 years        Male      Border    11.6
# 632   2012      20 - 24 years        Male        West    13.1
# 633   2012      20 - 24 years        Male    Mid-West    15.4
# 634   2012      20 - 24 years        Male  South-East    11.8
# 635   2012      20 - 24 years        Male  South-West    21.1
# 636   2012      20 - 24 years        Male      Dublin    43.0
# 637   2012      20 - 24 years        Male    Mid-East    18.1
# 638   2012      20 - 24 years        Male     Midland     7.5
# 639   2012      20 - 24 years      Female       State   143.6
# 640   2012      20 - 24 years      Female      Border    10.5
# 641   2012      20 - 24 years      Female        West    12.9
# 642   2012      20 - 24 years      Female    Mid-West    13.9
# 643   2012      20 - 24 years      Female  South-East    12.2
# 644   2012      20 - 24 years      Female  South-West    20.3
# 645   2012      20 - 24 years      Female      Dublin    46.1
# 646   2012      20 - 24 years      Female    Mid-East    19.3
# 647   2012      20 - 24 years      Female     Midland     8.4
# 648   2012      25 - 29 years  Both sexes       State   341.5
# 649   2012      25 - 29 years  Both sexes      Border    24.9
# 650   2012      25 - 29 years  Both sexes        West    29.1
# 651   2012      25 - 29 years  Both sexes    Mid-West    31.2
# 652   2012      25 - 29 years  Both sexes  South-East    26.8
# 653   2012      25 - 29 years  Both sexes  South-West    45.8
# 654   2012      25 - 29 years  Both sexes      Dublin   117.7
# 655   2012      25 - 29 years  Both sexes    Mid-East    45.1
# 656   2012      25 - 29 years  Both sexes     Midland    20.7
# 657   2012      25 - 29 years        Male       State   163.4
# 658   2012      25 - 29 years        Male      Border    12.4
# 659   2012      25 - 29 years        Male        West    13.9
# 660   2012      25 - 29 years        Male    Mid-West    15.3
# 661   2012      25 - 29 years        Male  South-East    12.9
# 662   2012      25 - 29 years        Male  South-West    21.9
# 663   2012      25 - 29 years        Male      Dublin    55.4
# 664   2012      25 - 29 years        Male    Mid-East    21.6
# 665   2012      25 - 29 years        Male     Midland    10.1
# 666   2012      25 - 29 years      Female       State   178.1
# 667   2012      25 - 29 years      Female      Border    12.6
# 668   2012      25 - 29 years      Female        West    15.2
# 669   2012      25 - 29 years      Female    Mid-West    15.9
# 670   2012      25 - 29 years      Female  South-East    13.9
# 671   2012      25 - 29 years      Female  South-West    24.0
# 672   2012      25 - 29 years      Female      Dublin    62.3
# 673   2012      25 - 29 years      Female    Mid-East    23.6
# 674   2012      25 - 29 years      Female     Midland    10.7
# 675   2012      30 - 34 years  Both sexes       State   394.0
# 676   2012      30 - 34 years  Both sexes      Border    28.9
# 677   2012      30 - 34 years  Both sexes        West    34.6
# 678   2012      30 - 34 years  Both sexes    Mid-West    36.3
# 679   2012      30 - 34 years  Both sexes  South-East    31.9
# 680   2012      30 - 34 years  Both sexes  South-West    54.7
# 681   2012      30 - 34 years  Both sexes      Dublin   127.6
# 682   2012      30 - 34 years  Both sexes    Mid-East    56.6
# 683   2012      30 - 34 years  Both sexes     Midland    23.4
# 684   2012      30 - 34 years        Male       State   193.3
# 685   2012      30 - 34 years        Male      Border    14.2
# 686   2012      30 - 34 years        Male        West    16.9
# 687   2012      30 - 34 years        Male    Mid-West    18.1
# 688   2012      30 - 34 years        Male  South-East    15.8
# 689   2012      30 - 34 years        Male  South-West    26.8
# 690   2012      30 - 34 years        Male      Dublin    62.4
# 691   2012      30 - 34 years        Male    Mid-East    27.5
# 692   2012      30 - 34 years        Male     Midland    11.5
# 693   2012      30 - 34 years      Female       State   200.8
# 694   2012      30 - 34 years      Female      Border    14.7
# 695   2012      30 - 34 years      Female        West    17.7
# 696   2012      30 - 34 years      Female    Mid-West    18.2
# 697   2012      30 - 34 years      Female  South-East    16.2
# 698   2012      30 - 34 years      Female  South-West    27.8
# 699   2012      30 - 34 years      Female      Dublin    65.2
# 700   2012      30 - 34 years      Female    Mid-East    29.1
# 701   2012      30 - 34 years      Female     Midland    11.9
# 702   2012      35 - 39 years  Both sexes       State   365.2
# 703   2012      35 - 39 years  Both sexes      Border    28.8
# 704   2012      35 - 39 years  Both sexes        West    33.3
# 705   2012      35 - 39 years  Both sexes    Mid-West    35.6
# 706   2012      35 - 39 years  Both sexes  South-East    31.5
# 707   2012      35 - 39 years  Both sexes  South-West    52.2
# 708   2012      35 - 39 years  Both sexes      Dublin   104.0
# 709   2012      35 - 39 years  Both sexes    Mid-East    57.3
# 710   2012      35 - 39 years  Both sexes     Midland    22.5
# 711   2012      35 - 39 years        Male       State   182.3
# 712   2012      35 - 39 years        Male      Border    14.4
# 713   2012      35 - 39 years        Male        West    16.4
# 714   2012      35 - 39 years        Male    Mid-West    18.0
# 715   2012      35 - 39 years        Male  South-East    15.9
# 716   2012      35 - 39 years        Male  South-West    26.3
# 717   2012      35 - 39 years        Male      Dublin    51.5
# 718   2012      35 - 39 years        Male    Mid-East    28.4
# 719   2012      35 - 39 years        Male     Midland    11.4
# 720   2012      35 - 39 years      Female       State   182.9
# 721   2012      35 - 39 years      Female      Border    14.3
# 722   2012      35 - 39 years      Female        West    16.9
# 723   2012      35 - 39 years      Female    Mid-West    17.6
# 724   2012      35 - 39 years      Female  South-East    15.6
# 725   2012      35 - 39 years      Female  South-West    25.8
# 726   2012      35 - 39 years      Female      Dublin    52.5
# 727   2012      35 - 39 years      Female    Mid-East    28.9
# 728   2012      35 - 39 years      Female     Midland    11.2
# 729   2012      40 - 44 years  Both sexes       State   334.6
# 730   2012      40 - 44 years  Both sexes      Border    27.8
# 731   2012      40 - 44 years  Both sexes        West    31.3
# 732   2012      40 - 44 years  Both sexes    Mid-West    33.9
# 733   2012      40 - 44 years  Both sexes  South-East    29.9
# 734   2012      40 - 44 years  Both sexes  South-West    48.5
# 735   2012      40 - 44 years  Both sexes      Dublin    88.9
# 736   2012      40 - 44 years  Both sexes    Mid-East    52.9
# 737   2012      40 - 44 years  Both sexes     Midland    21.4
# 738   2012      40 - 44 years        Male       State   168.0
# 739   2012      40 - 44 years        Male      Border    14.1
# 740   2012      40 - 44 years        Male        West    15.6
# 741   2012      40 - 44 years        Male    Mid-West    17.1
# 742   2012      40 - 44 years        Male  South-East    15.1
# 743   2012      40 - 44 years        Male  South-West    24.4
# 744   2012      40 - 44 years        Male      Dublin    44.1
# 745   2012      40 - 44 years        Male    Mid-East    26.6
# 746   2012      40 - 44 years        Male     Midland    10.9
# 747   2012      40 - 44 years      Female       State   166.6
# 748   2012      40 - 44 years      Female      Border    13.7
# 749   2012      40 - 44 years      Female        West    15.7
# 750   2012      40 - 44 years      Female    Mid-West    16.8
# 751   2012      40 - 44 years      Female  South-East    14.8
# 752   2012      40 - 44 years      Female  South-West    24.1
# 753   2012      40 - 44 years      Female      Dublin    44.8
# 754   2012      40 - 44 years      Female    Mid-East    26.3
# 755   2012      40 - 44 years      Female     Midland    10.5
# 756   2012      45 - 49 years  Both sexes       State   307.7
# 757   2012      45 - 49 years  Both sexes      Border    26.3
# 758   2012      45 - 49 years  Both sexes        West    29.8
# 759   2012      45 - 49 years  Both sexes    Mid-West    31.9
# 760   2012      45 - 49 years  Both sexes  South-East    28.7
# 761   2012      45 - 49 years  Both sexes  South-West    45.8
# 762   2012      45 - 49 years  Both sexes      Dublin    79.5
# 763   2012      45 - 49 years  Both sexes    Mid-East    46.7
# 764   2012      45 - 49 years  Both sexes     Midland    19.0
# 765   2012      45 - 49 years        Male       State   153.0
# 766   2012      45 - 49 years        Male      Border    13.2
# 767   2012      45 - 49 years        Male        West    15.0
# 768   2012      45 - 49 years        Male    Mid-West    15.9
# 769   2012      45 - 49 years        Male  South-East    14.2
# 770   2012      45 - 49 years        Male  South-West    23.1
# 771   2012      45 - 49 years        Male      Dublin    38.6
# 772   2012      45 - 49 years        Male    Mid-East    23.4
# ...
# 6411  2023      45 - 49 years        Male    Mid-West    18.3
# 6412  2023      45 - 49 years        Male  South-East    16.4
# 6413  2023      45 - 49 years        Male  South-West    27.4
# 6579  2023      75 - 79 years      Female       State    84.3
# 6580  2023      75 - 79 years      Female      Border     7.7
# 6581  2023      75 - 79 years      Female        West     8.4
# 6582  2023      75 - 79 years      Female    Mid-West     9.3
# 6583  2023      75 - 79 years      Female  South-East     8.1
# 6584  2023      75 - 79 years      Female  South-West    12.9
# 6585  2023      75 - 79 years      Female      Dublin    21.7
# 6586  2023      75 - 79 years      Female    Mid-East    11.1
# 6587  2023      75 - 79 years      Female     Midland     5.0
# 6588  2023      80 - 84 years  Both sexes       State   101.8
# 6589  2023      80 - 84 years  Both sexes      Border     9.3
# 6590  2023      80 - 84 years  Both sexes        West    10.8
# 6591  2023      80 - 84 years  Both sexes    Mid-West    11.0
# 6592  2023      80 - 84 years  Both sexes  South-East     9.9
# 6593  2023      80 - 84 years  Both sexes  South-West    15.6
# 6594  2023      80 - 84 years  Both sexes      Dublin    26.6
# 6595  2023      80 - 84 years  Both sexes    Mid-East    12.7
# 6596  2023      80 - 84 years  Both sexes     Midland     5.9
# 6597  2023      80 - 84 years        Male       State    46.1
# 6598  2023      80 - 84 years        Male      Border     4.5
# 6599  2023      80 - 84 years        Male        West     5.0
# 6600  2023      80 - 84 years        Male    Mid-West     5.0
# 6601  2023      80 - 84 years        Male  South-East     4.7
# 6602  2023      80 - 84 years        Male  South-West     7.0
# 6603  2023      80 - 84 years        Male      Dublin    11.4
# 6604  2023      80 - 84 years        Male    Mid-East     5.8
# 6605  2023      80 - 84 years        Male     Midland     2.7
# 6606  2023      80 - 84 years      Female       State    55.6
# 6607  2023      80 - 84 years      Female      Border     4.8
# 6608  2023      80 - 84 years      Female        West     5.8
# 6609  2023      80 - 84 years      Female    Mid-West     5.9
# 6610  2023      80 - 84 years      Female  South-East     5.2
# 6611  2023      80 - 84 years      Female  South-West     8.6
# 6612  2023      80 - 84 years      Female      Dublin    15.2
# 6613  2023      80 - 84 years      Female    Mid-East     6.9
# 6614  2023      80 - 84 years      Female     Midland     3.2
# 6615  2023  85 years and over  Both sexes       State    87.1
# 6616  2023  85 years and over  Both sexes      Border     8.1
# 6617  2023  85 years and over  Both sexes        West     9.6
# 6618  2023  85 years and over  Both sexes    Mid-West     9.0
# 6619  2023  85 years and over  Both sexes  South-East     8.1
# 6620  2023  85 years and over  Both sexes  South-West    13.4
# 6621  2023  85 years and over  Both sexes      Dublin    24.2
# 6622  2023  85 years and over  Both sexes    Mid-East     9.8
# 6623  2023  85 years and over  Both sexes     Midland     4.9
# 6624  2023  85 years and over        Male       State    33.1
# 6625  2023  85 years and over        Male      Border     3.1
# 6626  2023  85 years and over        Male        West     3.7
# 6627  2023  85 years and over        Male    Mid-West     3.5
# 6628  2023  85 years and over        Male  South-East     3.2
# 6629  2023  85 years and over        Male  South-West     5.3
# 6630  2023  85 years and over        Male      Dublin     8.6
# 6631  2023  85 years and over        Male    Mid-East     3.8
# 6632  2023  85 years and over        Male     Midland     2.0
# 6633  2023  85 years and over      Female       State    53.9
# 6634  2023  85 years and over      Female      Border     4.9
# 6635  2023  85 years and over      Female        West     5.9
# 6636  2023  85 years and over      Female    Mid-West     5.5
# 6637  2023  85 years and over      Female  South-East     5.0
# 6638  2023  85 years and over      Female  South-West     8.1
# 6639  2023  85 years and over      Female      Dublin    15.5
# 6640  2023  85 years and over      Female    Mid-East     6.0
# 6641  2023  85 years and over      Female     Midland     3.0
# 6642  2023           All ages  Both sexes       State  5281.6
# 6643  2023           All ages  Both sexes      Border   432.1
# 6644  2023           All ages  Both sexes        West   500.8
# 6645  2023           All ages  Both sexes    Mid-West   519.6
# 6646  2023           All ages  Both sexes  South-East   468.6
# 6647  2023           All ages  Both sexes  South-West   757.4
# 6648  2023           All ages  Both sexes      Dublin  1501.5
# 6649  2023           All ages  Both sexes    Mid-East   777.1
# 6650  2023           All ages  Both sexes     Midland   324.6
# 6651  2023           All ages        Male       State  2606.2
# 6652  2023           All ages        Male      Border   214.9
# 6653  2023           All ages        Male        West   247.9
# 6654  2023           All ages        Male    Mid-West   255.7
# 6655  2023           All ages        Male  South-East   231.1
# 6656  2023           All ages        Male  South-West   373.6
# 6657  2023           All ages        Male      Dublin   735.8
# 6658  2023           All ages        Male    Mid-East   385.8
# 6659  2023           All ages        Male     Midland   161.3
# 6660  2023           All ages      Female       State  2675.4
# 6661  2023           All ages      Female      Border   217.2
# 6662  2023           All ages      Female        West   252.9
# 6663  2023           All ages      Female    Mid-West   263.9
# 6664  2023           All ages      Female  South-East   237.5
# 6665  2023           All ages      Female  South-West   383.8
# 6666  2023           All ages      Female      Dublin   765.6
# 6667  2023           All ages      Female    Mid-East   391.3
# 6668  2023           All ages      Female     Midland   163.2

# %%
age_group= ['15 - 19 years','20 - 24 years', '25 - 29 years','30 - 34 years', '35 - 39 years','40 - 44 years', '45 - 49 years','50 - 54 years', '55 - 59 years','60 - 64 years']
filt = population_dataframe['age_group'].isin(age_group)
rando = population_dataframe.loc[filt]
working_age_bt_sex_state_df = rando.loc[(rando['sex'] == 'Both sexes') & (rando['region'] == 'State')].reset_index(drop=True)
working_age_bt_sex_state_df['value'].sum()*1000

### is total population between age group 15 - 64 from year 2011 to 2023
# Out:
# 41457899.99999999

# %%
year_grp = working_age_bt_sex_state_df.groupby(['year'])
year15 = year_grp.get_group(2012).reset_index(drop=True)
# count = [15, 20,25,30, 35, 40, 45, 50, 55, 60]
year15['value'].sum()
# Out:
# 3055.7

# %%
age_start = 15
for i in range(len(year15)):
    count = count.append(age_start)


ax.bar(year15, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()
# Out:
# Error in callback <function _draw_all_if_interactive at 0x7fcf08f419d0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in ?()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_pylab_helpers.py in ?(cls, force)
#     128         figures.
#     129         """
#     130         for manager in cls.get_all_fig_managers():
#     131             if force or manager.canvas.figure.stale:
# --> 132                 manager.canvas.draw_idle()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py in ?(self, *args, **kwargs)
#    2078
#    2079         """
#    2080         if not self._is_idle_drawing:
#    2081             with self._idle_draw_cntx():
# -> 2082                 self.draw(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in ?(self)
#     399               else nullcontext()):
#     400             self.figure.draw(self.renderer)
#     401             # A GUI class may be need to update a window using this draw, so
#     402             # don't forget to call the superclass.
# --> 403             super().draw()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in ?(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#      98             renderer._rasterizing = False
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in ?(artist, renderer)
#      78             if (renderer._rasterizing and artist.figure and
#      79                     artist.figure.suppressComposite):
#      80                 # restart rasterizing to prevent merging
#      81                 renderer.stop_rasterizing()
# ---> 82                 renderer.start_rasterizing()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in ?(self, renderer)
#    3179                 sfig.draw(renderer)
#    3180
#    3181             renderer.close_group('figure')
#    3182         finally:
# -> 3183             self.stale = False
#    3184
#    3185         DrawEvent("draw_event", self.canvas, renderer)._process()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in ?(renderer, parent, artists, suppress_composite)
#     127                      else renderer.option_image_nocomposite())
#     128
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#     134         image_group = []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in ?(artist, renderer)
#      78             if (renderer._rasterizing and artist.figure and
#      79                     artist.figure.suppressComposite):
#      80                 # restart rasterizing to prevent merging
#      81                 renderer.stop_rasterizing()
# ---> 82                 renderer.start_rasterizing()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in ?(self, renderer)
#    3020         # the frame draws the edges around the Axes patch -- we
#    3021         # decouple these so the patch can be in the background and the
#    3022         # frame in the foreground. Do this before drawing the axis
#    3023         # objects so that the spine has the opportunity to update them.
# -> 3024         if not (self.axison and self._frameon):
#    3025             for spine in self.spines.values():
#    3026                 artists.remove(spine)
#    3027
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in ?(self)
#    1525     @final
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py in ?(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2373             finally:
#    2374                 if bbox_inches and restore_bbox:
#    2375                     restore_bbox()
#    2376
# -> 2377             return result
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in ?(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#      98             renderer._rasterizing = False
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in ?(artist, renderer)
#      78             if (renderer._rasterizing and artist.figure and
#      79                     artist.figure.suppressComposite):
#      80                 # restart rasterizing to prevent merging
#      81                 renderer.stop_rasterizing()
# ---> 82                 renderer.start_rasterizing()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in ?(self, renderer)
#    3179                 sfig.draw(renderer)
#    3180
#    3181             renderer.close_group('figure')
#    3182         finally:
# -> 3183             self.stale = False
#    3184
#    3185         DrawEvent("draw_event", self.canvas, renderer)._process()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in ?(renderer, parent, artists, suppress_composite)
#     127                      else renderer.option_image_nocomposite())
#     128
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#     134         image_group = []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in ?(artist, renderer)
#      78             if (renderer._rasterizing and artist.figure and
#      79                     artist.figure.suppressComposite):
#      80                 # restart rasterizing to prevent merging
#      81                 renderer.stop_rasterizing()
# ---> 82                 renderer.start_rasterizing()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in ?(self, renderer)
#    3020         # the frame draws the edges around the Axes patch -- we
#    3021         # decouple these so the patch can be in the background and the
#    3022         # frame in the foreground. Do this before drawing the axis
#    3023         # objects so that the spine has the opportunity to update them.
# -> 3024         if not (self.axison and self._frameon):
#    3025             for spine in self.spines.values():
#    3026                 artists.remove(spine)
#    3027
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in ?(self)
#    1525     @final
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# uniquess = working_age_bt_sex_state_df.iloc[3:40, [0,4]]
uniquess

# %%
for age in range(len(unique_age)):
    
    print(unique_age[age])
    working_age_bt_sex_state_df = working_age_bt_sex_state_df.loc[(working_age_bt_sex_state_df['age_group'] != '15 - 19 years')]
